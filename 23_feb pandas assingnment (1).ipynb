# %%
Question 1: Create a Pandas series that contains the following data: 4,8,15,16,23, and 42. then, print the series.
Answer: 
#import pandas as pd
import pandas as pd
#creating a series
ser = pd.Series([4,8,15,16,23,42])
print(ser)

# %%
Question 2: Create a variable of list type containing 10 elements in it, and apply pandas. series function on the variable print it.
Answer: 
l = ['aditi','rathi',78,18,'pwskills','data science',23,12,56,'assingnment']
import pandas as pd
ser = pd.Series(l)
print(ser)

# %%
Question 3: Create a pandas dataframe that contains the following data:
    
    Name                         Age                          Gender
    
    Alice                       25                           Female
    Bob                         30                           Male
    Claire                      27                           Female
Then, print the DataFrame.

Answer: 
import pandas as pd
data = {'Name': ['Alice','Bob', 'Clarie']
        'Age': [25,30,27]
        'Gender':['Female','Male', 'Female']}
df = pd.DataFrame(data)
print(df)

# %%
Question 4: What is 'DataFrame' in pandas and how is it different from pandas.series? Explain with an example.
Answer: 
Pandas DataFrame is two-dimensional size-mutable, potentially heterogenous tabular data strucutre with labeled axes(rows and columns). A Data frame is a 
two-dimensional data structure,i.e., data is aligned in a tabular fashion in rows and columns. Pandas DataFrame consists of three principal componets,
the data, rows, and columns.
Example:
# Creating a Pandas Dataframe
In the real world, a pandas DataFrame will be created by loading the datasets from storage, storage can be SQL Database, CSV file, and Excel file. Panndas 
DataFrame can be created from the lists, dicitonary, and from a list od dictonary etc. DataFrame can be created in different ways here are some ways by which we
create a dataframes:
# Creating a dataframe using list: DataFrame can be created using a single list or a list of lists.

import pandas as pd
lst = ['pwskills','sudanshu','kumar','sir',56,57]
df = pd.DataFrame(lst)
print(df)

Differnce Between Pandas Series and Single Column DataFrame:  
Although a pandas and a DataFrame have many similarties. there are some key differnces between the two data structures.

                         
                                            Pandas Series                                   DataFrame

    Data Structre                            1D Table                                     2D Table
    Alignment                                Not supported                                Supported
    Columns                                  None0                                         1
    Functionality                            Less                                          More
    Index                                    Requried                                      Optional
    Perfomance                               Quick                                         Slow
    Name                                     Optional                                      Optional
    
As noted in the table, a pandas series is a 1D arrat of data, but a sing;e- column BataFrame is a 2D table with one column. The main distinction the two is this
DatFrame, an index can be optional, but a series has to have an infdex defined.

When to use Series or a single-column DataFrame?
When you use have one column of data and do not need to do any operations that call for a DataFrame, you should generally utilize a Pandas Series. When you
requrie the extra features of DataFrame such as filtering, ,merging, and joining, a single-column DataFrame should be employed.

When dealing with huge datasets, it is cruical to think about how employing a Series instead of a single-column dataFrame would affect perfomane.
For opreationms that only requrie one column of data, a series will typically be quicker than a single-column Dataframe.

# %%
Question 5: What are some common functions you can use to manipulate data in a pandas DataFrame? can you give an example of when you
might use one of these functions?
Answer: 
1.) Read Data
We can read data in pandas data frame as read_csv(). Two most used data read formats are cvs and excel. if we are reading in excel format, we can also give 
sheet names as follows. There are other less used options of other file types too.

import pandas as pd
df = pd.read_cvs("heart_failure.cvs")

df1 = pd.read_excel(open('heart_failure.xlsx','rb'), sheet_name = 'heart_failure'
                    

2.) Head and Tail:
to see the data frame we can use df.head(). Head returns the first  rows, if no input is given it will show above 5 rows.

3.) Shape, Size and Info
Two most basic functions after reading data is known the number of rows and columns, and to know the datatype of variables. we can use df.shape , it gives a 
total number of rows and then columns. df.size() returns the number of rows times of columns in data frame. We can also use df.info(), from that we get
different information such as rows from RangeIndex, Data columns and then data type of each column. it also includes the information of non-null counts.

4.) isna
But, if one needs to get the total number of null values in data, we can use df.isna() as below. Sum will give the total null values. if we want just one
variable null values, we can also get it giving the name of the variable as below.

5.) Describe
Then to understand basic statistics of variable we can use df.describe(). it will give you count, mean, standard deviation, and also 5 number summary.

6.) Nunique
to get the total unique values of variables, we can use df.nunique(). It will give all the unique values a variable contains.

7.) Value Counts
Also to get he unique values of single variable, we can use df.anaemia.value_counts(). For demonstration, only variables with boolean values are given below. 
count_values() returns counts of unique values. The resulting object will be in descending order. This function excludes NA values by default.

8.) Columns
To know the names of all the variables in data frame, we can use df.columns.

Hence, These functions are very common to preprocess he data in the initial steps. Even memorizing these functions is good idea. There are many other useful 
functions and can be used as per condition and requirement.

# %%
Question 6: Which of the following is mutable in nature series, DataFrame, Panel?
Answer: 
All Pandas structures are value mutable(can be changed) and except series all the size mutable.
Series is size immutable.
# Note: DataFrame is widely used and one of the most important data structures. Panel is used much less.

DataFrame and Panel are mutable.
Series is immutable.

# %%
Question 7: Create a DataFrame using multiple Series. Explain with an example.
Answer: 
Create pandas DataFrame From Multiple Series:
    
You can create a DataFrame from multiple Series Objects adding each series as a columns.

By using concat() method you can merge multiple series togther into DataFrame. This takes several params, for our scenario we use list that takes series 
to combine and axis =1 to pecify merge series as columns instead of rows. Note that using axis = 0 appends to rows instead of columns

Example:

import pandas as pd
#create pandas series
coursers = pd.Series(["spark", "pyspark","Hadoop"])
fees = pd.Series([22000,25000,23000])
discount = pd.Series([1000, 2300, 1000])

#combine two series
df = pd.concat([courses,fees],axis=1)
#it also supports to combine multiple series.
df = pd.concat([courses, fees, discount], axis= 1)
print(df)

#output:   

        0           1                2

0   spark       22000              1000
1   pyspark     25000              2300
2   Hadoop      23000              1000

# %%
for i in range(1000):
    print( i **8)
# Out:
# 0
# 1
# 256
# 6561
# 65536
# 390625
# 1679616
# 5764801
# 16777216
# 43046721
# 100000000
# 214358881
# 429981696
# 815730721
# 1475789056
# 2562890625
# 4294967296
# 6975757441
# 11019960576
# 16983563041
# 25600000000
# 37822859361
# 54875873536
# 78310985281
# 110075314176
# 152587890625
# 208827064576
# 282429536481
# 377801998336
# 500246412961
# 656100000000
# 852891037441
# 1099511627776
# 1406408618241
# 1785793904896
# 2251875390625
# 2821109907456
# 3512479453921
# 4347792138496
# 5352009260481
# 6553600000000
# 7984925229121
# 9682651996416
# 11688200277601
# 14048223625216
# 16815125390625
# 20047612231936
# 23811286661761
# 28179280429056
# 33232930569601
# 39062500000000
# 45767944570401
# 53459728531456
# 62259690411361
# 72301961339136
# 83733937890625
# 96717311574016
# 111429157112001
# 128063081718016
# 146830437604321
# 167961600000000
# 191707312997281
# 218340105584896
# 248155780267521
# 281474976710656
# 318644812890625
# 360040606269696
# 406067677556641
# ...
